# %%
import cv2 as cv 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# !pip install tifffile
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\Javier\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# Path to the multipage TIFF file
input_tiff_path = "mask000.tif"

# Create an output directory at the same level as the TIFF file
output_directory = os.path.join(os.path.dirname(input_tiff_path), "exp0_frames_test")
os.makedirs(output_directory, exist_ok=True)

# Load all frames from the multipage TIFF
frames = []
success, frames = cv2.imreadmulti(input_tiff_path, [], cv2.IMREAD_UNCHANGED)

if success:
    print(f"Successfully read {len(frames)} frames from the TIFF file.")

    # Iterate over each frame and save it as a separate image
    for i, frame in enumerate(frames):
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        output_path = os.path.join(output_directory, f"frame_{i+1}.tif")
        tiff.imwrite(output_path, frame_rgb, photometric='rgb', compression=None)
        #cv2.imwrite(output_path, frame, [cv2.IMWRITE_TIFF_COMPRESSION, 0])
        print(f"Saved frame {i+1} to {output_path}")
else:
    print("Failed to read the TIFF file. Please check the file path or format.")
